# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Import the data/csv file & preview
original = pd.read_csv("vacasa_data.csv")
df = pd.read_csv("vacasa_data.csv")
df
# Out:
#        unit_id check_in_date check_out_date reservation_type  \
# 0        40630      1/1/2018       1/3/2018            guest
# 1        40630      1/3/2018       1/7/2018            guest
# 2        40630     1/11/2018      1/15/2018            guest
# 3        40630     1/15/2018      1/18/2018            owner
# 4        40630     1/20/2018      1/21/2018            guest
# ...        ...           ...            ...              ...
# 92540    21239      4/9/2019      4/12/2019            guest
# 92541    21239     4/12/2019      4/14/2019            guest
# 92542    21239     4/14/2019      4/16/2019            guest
# 92543    21239     4/16/2019      5/31/2019            owner
# 92544    21239     5/31/2019     12/31/2021            owner
#
#              reservation_source_type reservation_created_date  adult_guests  \
# 0                            unknown                 1/1/2018             2
# 1                            unknown                 1/3/2018             2
# ...

# %% [markdown]
# #### ^ This shows me that there were a total of 92,545 reservations in this dataset.

# %%
# Find all reservations 
df['unit_id'].value_counts()
# Out:
# 9131     177
# 11033    163
# 12006    161
# 10143    159
# 9390     159
#         ...
# 42492      1
# 62902      1
# 18488      1
# 43032      1
# 42445      1
# Name: unit_id, Length: 2197, dtype: int64

# %% [markdown]
# #### ^ This shows me there are currently 2,197 different units.
# #### This also shows the top 5 most used units

# %%
# Remove $ and , from total_paid
df['total_paid'] = df['total_paid'].str.replace('$', '')
df['total_paid'] = df['total_paid'].str.replace(',', '')
df
# Out:
#        unit_id check_in_date check_out_date reservation_type  \
# 0        40630      1/1/2018       1/3/2018            guest
# 1        40630      1/3/2018       1/7/2018            guest
# 2        40630     1/11/2018      1/15/2018            guest
# 3        40630     1/15/2018      1/18/2018            owner
# 4        40630     1/20/2018      1/21/2018            guest
# ...        ...           ...            ...              ...
# 92540    21239      4/9/2019      4/12/2019            guest
# 92541    21239     4/12/2019      4/14/2019            guest
# 92542    21239     4/14/2019      4/16/2019            guest
# 92543    21239     4/16/2019      5/31/2019            owner
# 92544    21239     5/31/2019     12/31/2021            owner
#
#              reservation_source_type reservation_created_date  adult_guests  \
# 0                            unknown                 1/1/2018             2
# 1                            unknown                 1/3/2018             2
# ...

# %%
# Remove rows that have $0 sales
df.drop(df.loc[df['total_paid']== "0"].index, inplace=True)
df
# Out:
#        unit_id check_in_date check_out_date reservation_type  \
# 0        40630      1/1/2018       1/3/2018            guest
# 1        40630      1/3/2018       1/7/2018            guest
# 2        40630     1/11/2018      1/15/2018            guest
# 3        40630     1/15/2018      1/18/2018            owner
# 4        40630     1/20/2018      1/21/2018            guest
# ...        ...           ...            ...              ...
# 92536    21239      3/9/2019      3/13/2019            guest
# 92538    21239     3/21/2019      3/24/2019            guest
# 92540    21239      4/9/2019      4/12/2019            guest
# 92541    21239     4/12/2019      4/14/2019            guest
# 92542    21239     4/14/2019      4/16/2019            guest
#
#              reservation_source_type reservation_created_date  adult_guests  \
# 0                            unknown                 1/1/2018             2
# 1                            unknown                 1/3/2018             2
# ...

# %%
# Get value counts for all unit_id numbers
df['unit_id'].value_counts()
# Out:
# 9131     157
# 11033    146
# 6309     145
# 17653    143
# 40618    143
#         ...
# 31087      1
# 31237      1
# 9107       1
# 30653      1
# 17594      1
# Name: unit_id, Length: 2125, dtype: int64

# %% [markdown]
# #### ^ I was curious what the rentals looked like without the ones that may have cancelled. Which, if the 0 amount paid is due to cancellation, then the answer would be 72,456 complete reservations total in the dataset & 2,125 units that were actually used.
#
# #### Working on the same assumption, it would also mean there were a total of 20,089 cancellations and 72 units that were not used.

# %%
#renaming dataframe
zero_sales = df
zero_sales
# Out:
#        unit_id check_in_date check_out_date reservation_type  \
# 0        40630      1/1/2018       1/3/2018            guest
# 1        40630      1/3/2018       1/7/2018            guest
# 2        40630     1/11/2018      1/15/2018            guest
# 3        40630     1/15/2018      1/18/2018            owner
# 4        40630     1/20/2018      1/21/2018            guest
# ...        ...           ...            ...              ...
# 92536    21239      3/9/2019      3/13/2019            guest
# 92538    21239     3/21/2019      3/24/2019            guest
# 92540    21239      4/9/2019      4/12/2019            guest
# 92541    21239     4/12/2019      4/14/2019            guest
# 92542    21239     4/14/2019      4/16/2019            guest
#
#              reservation_source_type reservation_created_date  adult_guests  \
# 0                            unknown                 1/1/2018             2
# 1                            unknown                 1/3/2018             2
# ...

# %%
# Save dataframe to csv 
zero_sales.to_csv(r'cleaned_data.csv')

# %% [markdown]
# #### ^ Saved dataframe that was cleaned up to do a second analysis on it

# %%
# Preview original df again
original
# Out:
#        unit_id check_in_date check_out_date reservation_type  \
# 0        40630      1/1/2018       1/3/2018            guest
# 1        40630      1/3/2018       1/7/2018            guest
# 2        40630     1/11/2018      1/15/2018            guest
# 3        40630     1/15/2018      1/18/2018            owner
# 4        40630     1/20/2018      1/21/2018            guest
# ...        ...           ...            ...              ...
# 92540    21239      4/9/2019      4/12/2019            guest
# 92541    21239     4/12/2019      4/14/2019            guest
# 92542    21239     4/14/2019      4/16/2019            guest
# 92543    21239     4/16/2019      5/31/2019            owner
# 92544    21239     5/31/2019     12/31/2021            owner
#
#              reservation_source_type reservation_created_date  adult_guests  \
# 0                            unknown                 1/1/2018             2
# 1                            unknown                 1/3/2018             2
# ...

# %%
# Get count of reservations at Vail / Beaver Creek
original['region_name_short'].value_counts()
# Out:
# The Texas Gulf Coast    33004
# Delaware                29830
# Vail / Beaver Creek     29711
# Name: region_name_short, dtype: int64

# %% [markdown]
# #### ^ Total reservation at Vail / Beaver Creek= 29,711

# %%
# Get number of child guests in df. 
original['child_guests'].value_counts().describe()
# Out:
# count       22.000000
# mean      4206.590909
# std      15605.551999
# min          2.000000
# 25%          6.000000
# 50%         61.500000
# 75%        700.500000
# max      73593.000000
# Name: child_guests, dtype: float64

# %%
original['child_guests'].value_counts()
# Out:
# 0     73593
# 2      7039
# 1      4814
# 3      3085
# 4      2103
# 5       784
# 6       450
# 8       204
# 7       176
# 10       82
# 12       64
# 9        59
# 11       29
# 15       22
# 14       12
# 13        9
# 18        5
# 16        4
# 99        4
# 19        3
# 20        2
# 17        2
# Name: child_guests, dtype: int64

# %%
# Divide # of children (max = 73593) / # of reservations (92545)
np.true_divide(73593, 92545)
# Out:
# 0.7952131395537306

# %% [markdown]
# #### % of reservations had children = 79.52%

# %%
np.true_divide(92545, 73593)
# Out:
# 1.2575244928186105

# %%
# 309 is total # on left column of child_guests value counts row. 
np.true_divide(309, 92545)
# Out:
# 0.003338916202928305

# %% [markdown]
# #### Average number of children on a reservation = 3
